# %%
arr1 = 393958954
arr2 = -1182209976 & 0xffffffff
arr3 = -749021218 & 0xffffffff
arr4 = 246806259

res = (arr3 | (arr1 & arr4 + arr3) + arr3 + arr3 & arr2 + arr4) & arr4
print(res, hex(res))
# Out:
# 169137906 0xa14d6f2

# %%
arr1 = 393958954
arr2 = -1182209976 & 0xffffffff
arr3 = -749021218 & 0xffffffff
arr4 = 246806259

res = (arr3 | ((((arr1 & (arr4 + arr3)) + arr3) + arr3) & (arr2 + arr4))) & arr4
print(res, hex(res))
# Out:
# 169137906 0xa14d6f2
